# %% [markdown]
# # Correlation functions

# %%
import numpy as np
def noise(T):
    sigma=np.sqrt(T) # ignore Boltzmann's constant
    x=np.random.normal(0,sigma,10000000) # give me lots of values
    return x
ant1=noise(30)


# %pylab inline
sigma =np.std(ant1, ddof=1)

count, bins, ignored = pylab.hist(s, 40,normed=True)
pylab.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *np.exp( - (bins)**2 / (2 * sigma**2) ),linewidth=2, color='r')
pylab.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['correlate']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
ant2=noise(30)
signal=noise(1)

# %%
sigma=np.std(ant2+signal, ddof=1)

count, bins, ignored = pylab.hist(ant2+signal, 40, normed=True)
pylab.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *np.exp( - (bins)**2 / (2 * sigma**2) ),linewidth=2, color='r')
pylab.show()

# %%
sigma=np.std(signal, ddof=1)
count, bins, ignored = pylab.hist(signal, 40, normed=True)
pylab.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *np.exp( - (bins)**2 / (2 * sigma**2) ),linewidth=2, color='r')
pylab.show()

# %%
def correlate(x,y,n=10000):
    prod=x*y
    av=numpy.mean(prod.reshape(-1, n), 1) # average up by n; n must divide into the array length
    return av

p=correlate(ant1,ant2)
print len(p),len(ant1)
# Out:
# 1000 10000000

# %%
pylab.plot(ant1)
pylab.show()

# %%
#what does it look like
pylab.plot(correlate(ant1,ant1))
pylab.plot(correlate(ant2,ant2))
pylab.plot(correlate(ant1,ant2))
pylab.show()

# %% [markdown]
# # What about adding in a signal from the source

# %%
s1=ant1+signal
s2=ant2+signal

# %%
pylab.plot(correlate(s1,s1))
pylab.plot(correlate(s2,s2))
pylab.plot(correlate(s1,s2))
pylab.show()

# %%
print np.mean(correlate(ant1,ant2))
print np.mean(correlate(s1,s2))
print np.mean(s1),np.mean(s2), np.var(signal)/np.sqrt(1e4)
print np.var(s1), np.var(s2) # both about 31 = noise+signal
print np.var(ant1),np.var(ant2) # both about 30 = noise
print np.var(correlate(s1,s2))
# Out:
# -0.00662418937611
# 0.994547167606
# -0.00285464654782
# 0.000377286155194
# 0.0100029430101
# 30.9971516537
#  30.98034716
# 29.997783985
#  29.9773743078
# 0.0915954546247

# %%
# number of samples are len(s1)
# so expect noise to be var(s1)/len(s1)

# %%
#noiselevel  = np.var(s1)/np.sqrt(len(s1))
noiselevel=np.var(correlate(s1,s2))
found=np.mean(correlate(s1,s2))
snr= found/noiselevel
print "Noise level", noiselevel,"Signal found", found,"SNR",snr # with 1e4 integration times
print "power ratio", np.var(signal)/np.var(ant1)
# Out:
# Noise level 0.0915954546247 Signal found 0.994547167606 SNR 10.8580406275
# power ratio
# 0.0333456065125
