# %%
"""Get 2 sinusoid waves, add noise - plotDo FFT  - plot"""from scipy import sin,cos,fft,ifft#from pylab import *%pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
t=arange(-50,50,0.01) # time axiss=sin(2*2*pi*t)c=cos(3*2*pi*t)#print fc,fs#s=zeros(len(t))#c=zeros(len(t))noise=3*randn(len(t)) # gaussian random noise much biggersignal=s+c+noise# plot itpylab.figure(1,figsize(12,12))plot(t,noise,label="Gaussian noise")plot(t,signal,label="sum")plot (t,s,label="$sin(2\pi 2t)$") #nice greek letterplot (t,c,label="$cos(2\pi 3t)$")legend()pylab.show()

# %%
#pylab.figure(2)scale=30./len(t)print ifft(signal)pylab.plot(t,scale*real(fftshift(ifft(signal))),label='real fft')pylab.plot(t,scale*imag(fftshift(ifft(signal))),label='imag fft')pylab.xlim(xmin=0,xmax=10) # only positive axispylab.legend()pylab.show()
# Out:
# [ 0.03150608+0.j          0.01992619+0.00348787j  0.02625145+0.01656989j ..., -0.00085880-0.00949947j  0.02625145-0.01656989j  0.01992619-0.00348787j]
