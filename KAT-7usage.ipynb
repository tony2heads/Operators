# %%
import katarchive
#import katdal as katfile
import katfile
import datetime

import logging
logging.root.setLevel(logging.ERROR)

# %%
f = katarchive.search_archive(startdate='03/06/2014')
start = datetime.datetime.strptime(f[-1].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
end = datetime.datetime.strptime(f[0].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-f8431977e346> in <module>()
# ----> 1 f = katarchive.search_archive(startdate='03/06/2014')
#       2 start = datetime.datetime.strptime(f[-1].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
#       3 end = datetime.datetime.strptime(f[0].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
#
# /usr/local/lib/python2.7/dist-packages/katarchive-trunk-py2.7.egg/katarchive/view.pyc in search_archive(observer, target, description, filename, startdate, enddate)
#      26
#      27     """
# ---> 28     search_result, search_string = db.listing(observer, target, description, filename, startdate, enddate)
#      29     print 'Searched using: %s' % (search_string)
#      30     print 'Returning %d results' % len(search_result)
#
# /usr/local/lib/python2.7/dist-packages/katarchive-trunk-py2.7.egg/katarchive/db.pyc in listing(observer, target, description, filename, startdate, enddate, rows)
#      51     if search_list:
#      52         search_string = ' AND '.join(search_list)
# ---> 53     return archive.search(search_string, rows=rows, sort=sort_string).docs, search_string
#
# /usr/local/lib/python2.7/dist-packages/pysolr.pyc in search(self, q, **kwargs)
#     601         params = {'q': q}
#     602         params.update(kwargs)
# --> 603         response = self._select(params)
#     604
#     605         # TODO: make result retrieval lazy and allow custom result objects
#
# /usr/local/lib/python2.7/dist-packages/pysolr.pyc in _select(self, params)
#     331             # Typical case.
#     332             path = 'select/?%s' % params_encoded
# --> 333             return self._send_request('get', path)
#     334         else:
#     335             # Handles very long queries by submitting as a POST.
#
# /usr/local/lib/python2.7/dist-packages/pysolr.pyc in _send_request(self, method, path, body, headers, files)
#     316
#     317         if int(resp.status_code) != 200:
# --> 318             error_message = self._extract_error(resp)
#     319             self.log.error(error_message, extra={'data': {'headers': resp.headers,
#     320                                                           'response': resp.content}})
#
# /usr/local/lib/python2.7/dist-packages/pysolr.pyc in _extract_error(self, resp)
#     395
#     396         if reason is None:
# --> 397             reason, full_html = self._scrape_response(resp.headers, resp.content)
#     398
#     399         msg = "[Reason: %s]" % reason
#
# /usr/local/lib/python2.7/dist-packages/pysolr.pyc in _scrape_response(self, headers, response)
#     427             soup = lxml.html.fromstring(response)
#     428             body_node = soup.find('body')
# --> 429             p_nodes = body_node.cssselect('p')
#     430
#     431             for p_node in p_nodes:
#
# AttributeError: 'NoneType' object has no attribute 'cssselect'

# %%
print 'First file in run: ' , start.isoformat()
print 'Last file in run: ' , end.isoformat()
# Out:
# First file in run:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b353abd67114> in <module>()
# ----> 1 print 'First file in run: ' , start.isoformat()
#       2 print 'Last file in run: ' , end.isoformat()
#
# NameError: name 'start' is not defined

# %% [markdown]
# Only select observations that are longer than 1 hrs then extract the project id from the script parameters. If there is no project id then allocated No_project_id

# %%
sbd = []
pid = []
fnd = []
dud = []
antsd = []
scrd = []

for fi in f:
    if fi.metadata.Duration < 3600: #only pick hour long or greater observations for analysis
        continue
    # now try extract the project-id from the instruction-set string
    script = fi.metadata.InstructionSet
    scrd.append(script)
    spl = script.split()
    for i,s in enumerate(spl):
        if u'--project-id' in s:
            if '=' in s: #some people use --project-id=yyyymmddNN-01 and some --project-id yyyymmddNN-01
                p = s.split('=')[-1]
            else:
                p = spl[i+1]
            break
        else:
            if u'G9.62' in s: # special case for the masers that dont have ids
                p = 'Maser'
                break
            p = 'No-project-id' 
    sbd.append(fi.metadata.ExperimentID)
    pid.append(p)
    fnd.append(fi.metadata.Filename)
    dud.append(fi.metadata.Duration)
    antsd.append(len(fi.metadata.Antennas))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c96bfb5053d4> in <module>()
#       6 scrd = []
#       7
# ----> 8 for fi in f:
#       9     if fi.metadata.Duration < 3600: #only pick hour long or greater observations for analysis
#      10         continue
#
# NameError: name 'f' is not defined

# %%
pi = array(pid)
sb = array(sbd)
du = array(dud)
ants = array(antsd)

p_cent = (sum(du)/((end.toordinal()-start.toordinal())*24*3600))*100

print 'Percentage system usage: ', floor(p_cent),'%'
# Out:
# Percentage system usage:  82.0 %

# %% [markdown]
# Find the unique project ids and determine the total observation duration.

# %%
a_id = []
a_time = []
for p in set(pi):
    ind = pi == p
    print p,round(sum(du[ind])/3600,2)
    a_id.append(p)
    a_time.append(round(sum(du[ind])/3600,2))
# Out:
# COMMTEST 26.6
# 20131103DL-01 10.51
# Maser 11.88
# 20130822NO-01 8.04
# 20140529GB-01 6.05
# 20131211NO-01 5.09
# 20130821SG-01 13.31
# 20140527TF-01 5.0
# 20140520RA-01 8.09
# 20130821TM-01 5.89
# 20140513DL-01 18.96
# No-project-id 22.5
# 20140603MC-01 8.27
# 20130822OP-02 9.04

# %% [markdown]
# Sort ID and time for display

# %%
ind = argsort(a_id)
for i in ind:
    print a_id[i],a_time[i]
# Out:
# 20130821SG-01 13.31
# 20130821TM-01 5.89
# 20130822NO-01 8.04
# 20130822OP-02 9.04
# 20131103DL-01 10.51
# 20131211NO-01 5.09
# 20140513DL-01 18.96
# 20140520RA-01 8.09
# 20140527TF-01 5.0
# 20140529GB-01 6.05
# 20140603MC-01 8.27
# COMMTEST 26.6
# Maser 11.88
# No-project-id 22.5

# %% [markdown]
# Plot as pie-chart

# %%
figure(figsize=(15,15))
pie(a_time,labels=a_id,autopct='%1.1f%%');
